# %% [markdown]
# # PYTHON FOR EVERYBODY - UNIVERSITY OF MICHIAN
# ## CURSO 3 - Using Python to Access Web Data
#
# This course will show how one can treat the Internet as a source of data. We will scrape, parse, and read web data as well as access data using web APIs. We will work with HTML, XML, and JSON data formats in Python. This course will cover Chapters 11-13 of the textbook “Python for Everybody”. To succeed in this course, you should be familiar with the material covered in Chapters 1-10 of the textbook and the first two courses in this specialization. These topics include variables and expressions, conditional execution (loops, branching, and try/except), functions, Python data structures (strings, lists, dictionaries, and tuples), and manipulating files. This course covers Python 3.

# %% [markdown]
#  ## Regular Expressions
#
# In computing, a regular expression, also referred to as “regex” or “regexp”, provides a concise and flexible means for matching strings of text, such as particular characters, words, or patterns of characters. A regular expression is written in a formal language that can be interpreted by a regular expression processor.
#
# Before you can use regular expressions in your program, you must import the library using “import re”
#  - You can use re.search() to see if a string matches a regular expression, similar to using the find() method for strings
#  - You can use re.findall() to extract portions of a string that match your regular expression, similar to a combination of find() and slicing:  var[5:10]

# %%
#   IMPORTANDO DADOS NO COLAB DO DRIVE
## primeiro vc tem q chara o seu drive para o colab, montando ele 

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#   IMPORTANDO DADOS NO COLAB DO DRIVE
## em seguida vc chamar o arquivo

romeo = open ('/content/drive/My Drive/Cursos/Data Science/Python for Everybody/2 Python Data Structures/romeo.txt')
mbox = open ('/content/drive/My Drive/Cursos/Data Science/Python for Everybody/2 Python Data Structures/mbox-short.txt')
words = open ('/content/drive/My Drive/Cursos/Data Science/Python for Everybody/2 Python Data Structures/words.txt')
regex_sum_assig = open ('/content/drive/My Drive/Cursos/Data Science/Python for Everybody/3 Using Python to Access Web Data/regex_sum_1006553.txt')
regex_sum_42 = open ('/content/drive/My Drive/Cursos/Data Science/Python for Everybody/3 Using Python to Access Web Data/regex_sum_42.txt')

# %%
# PARA FAZER UMA PESQUISA PODEMOS UTILIZAR O COMANDO :find ()

mbox  = open ('/content/drive/My Drive/Cursos/Data Science/Python for Everybody/2 Python Data Structures/mbox-short.txt')
for line in mbox :
   line = line.rstrip()
   if line.find ('From:') >=0:
     print (line)
# Out:
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: wagnermr@iupui.edu
# From: zqian@umich.edu
# From: antranig@caret.cam.ac.uk
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: louis@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu

# %%
# MAS OUTRA FORMS É UTILIZAR AS EXPRESSÕES REGULARES E  COM ELA UTILZIAR O COMANDO : re.searcg('O QUE PROCURO', VARIVALE QUE ESTÁ )


import re ## biblioteca necessária para trabalhar com a expressões regulares

mbox  = open ('/content/drive/My Drive/Cursos/Data Science/Python for Everybody/2 Python Data Structures/mbox-short.txt')
for line in mbox :
   line = line.rstrip()
   if re.search('From:', line):
     print (line)
# Out:
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: wagnermr@iupui.edu
# From: zqian@umich.edu
# From: antranig@caret.cam.ac.uk
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: louis@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu

# %%
# PODEMOS  TAMBME TROCAR O COMANDO : starwith 

mbox  = open ('/content/drive/My Drive/Cursos/Data Science/Python for Everybody/2 Python Data Structures/mbox-short.txt')
for line in mbox :
   line = line.rstrip()
   if line.startswith ('From:') :
     print (line)
# Out:
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: wagnermr@iupui.edu
# From: zqian@umich.edu
# From: antranig@caret.cam.ac.uk
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: louis@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu

# %%
# PARA USAR O COMANDO re.search nesse caso temos que utilizar algumas expressões expecificas  

mbox  = open ('/content/drive/My Drive/Cursos/Data Science/Python for Everybody/2 Python Data Structures/mbox-short.txt')
for line in mbox :
   line = line.rstrip()
   if re.search ('^From:', line) : # ^ indica que o que procuramos inicia com From:
     print (line)
# Out:
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: wagnermr@iupui.edu
# From: zqian@umich.edu
# From: antranig@caret.cam.ac.uk
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: louis@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu

# %% [markdown]
# •	The dot (.) character matches any character
#
# •	If you add the asterisk (*) character, the character is “any number of times”
#
# •	The\S match with any non -whitespace character
#
# •	The [0-9]+ --> one or more digites

# %% [markdown]
# ### Matching and Extracting Data
#
# •	re.search() --> returns a True/False depending on whether the string matches  the regular expression
#
# •	If we actually want the matching strings to be extracted, we use **re.findall()**

# %%
x = 'My 2 favorite numbers are 19 and 42'
y = re.findall('[0-9]+',x)
print(y)
# Out:
# ['2', '19', '42']

# %%
# When we use re.findall(), it returns a list of zero or more sub-strings that match the regular expression

x = 'My 2 favorite numbers are 19 and 42'
y = re.findall('[aeiou]+',x)
print(y)
# Out:
# ['a', 'o', 'i', 'e', 'u', 'e', 'a', 'e', 'a']

# %%
# OBSERVAR Q PYTHON DIFERENCIA ENTRE MAIUSCULA E MINUSCULA, MESMO NOS COMANDO REGEX

x = 'My 2 favorite numbers are 19 and 42'
y = re.findall('[AEIOU]+',x)
print(y)
# Out:
# []

# %% [markdown]
# ### Greedy and non- greedy matching
#
# The repeat characters (* and +) push outward in both directions (greedy) to match the largest possible string
#
# Not all regular expression repeat codes are greedy!  If you add a "?" character, the + and * chill out a bit

# %%
a = 'From Using the : caractere'
b = re.findall('^F.+:', a)
print (b)

x = 'From: Using the : character'
y = re.findall('^F.+?:', x)
print(y)
# Out:
# ['From Using the :']
# ['From:']

# %% [markdown]
# ### Fine-Tuning String Extraction
#
# You can refine the match for re.findall() and separately determine which portion of the match is to be extracted by using parentheses

# %%
# \S At least one non-whitespace character

a = 'From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008'
b = re.findall('\S+@\S+', a)   
print (b)
# Out:
# ['stephen.marquard@uct.ac.za']

# %%
# OS PARENTESES VÃO DIZER ONDE COMEÇAR A EXTRAÇÃO DOS DADOS
a = 'From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008'
b = re.findall('^From (\S+@\S+)', a)
print (b)
# Out:
# ['stephen.marquard@uct.ac.za']

# %%
data = 'From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008'
X = data.find('@')
print(X)
Y = data.find(' ',X)
print(Y)
result = data[X+1 : Y]
print(result)
# Out:
# 21
# 31
# uct.ac.za

# %% [markdown]
# ### The Double Split Pattern
#
# Sometimes we split a line one way, and then grab one of the pieces of the line and split that piece again

# %%
mbox = open ('/content/drive/My Drive/Cursos/Data Science/Python for Everybody/2 Python Data Structures/mbox-short.txt')
for line in mbox:
  line = line.rstrip()
  if not line.startswith ('From'): continue
  words = line.split ()
  email = words[1]
  
  pieces = email.split('@')
  
  print (pieces[1])
# Out:
# uct.ac.za
# uct.ac.za
# media.berkeley.edu
# media.berkeley.edu
# umich.edu
# umich.edu
# iupui.edu
# iupui.edu
# umich.edu
# umich.edu
# iupui.edu
# iupui.edu
# iupui.edu
# iupui.edu
# iupui.edu
# iupui.edu
# umich.edu
# umich.edu
# umich.edu
# umich.edu
# umich.edu
# umich.edu
# umich.edu
# umich.edu
# iupui.edu
# iupui.edu
# umich.edu
# umich.edu
# caret.cam.ac.uk
# caret.cam.ac.uk
# gmail.com
# gmail.com
# uct.ac.za
# uct.ac.za
# uct.ac.za
# uct.ac.za
# uct.ac.za
# uct.ac.za
# uct.ac.za
# uct.ac.za
# uct.ac.za
# uct.ac.za
# media.berkeley.edu
# media.berkeley.edu
# media.berkeley.edu
# media.berkeley.edu
# media.berkeley.edu
# media.berkeley.edu
# iupui.edu
# iupui.edu
# iupui.edu
# iupui.edu
# iupui.edu
# iupui.edu

# %%
# Look through the string until you find an at sign

data = 'From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008'
x = re.findall('@([^ ]*)', data)

print (x)
# Out:
# ['uct.ac.za']

# %% [markdown]
# ### The Regex Version

# %%
lin = 'From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008'
y = re.findall('^From .*@([^ ]*)',lin)
print(y)
# Out:
# ['uct.ac.za']

# %% [markdown]
# ### Spam Confidence

# %%
hand = open ('/content/drive/My Drive/Cursos/Data Science/Python for Everybody/2 Python Data Structures/mbox-short.txt')
numlist = list()
for line in hand:
    line = line.rstrip()
    stuff = re.findall('^X-DSPAM-Confidence: ([0-9.]+)', line)## O PONTO (.) EM [0-9.] É PARA BUSCAR POR FLOAT 
    if len(stuff) != 1 :  continue
    num = float(stuff[0])
    numlist.append(num)
    print (numlist)
print('Maximum:', max(numlist))
# Out:
# [0.8475]
# [0.8475, 0.6178]
# [0.8475, 0.6178, 0.6961]
# [0.8475, 0.6178, 0.6961, 0.7565]
# [0.8475, 0.6178, 0.6961, 0.7565, 0.7626]
# [0.8475, 0.6178, 0.6961, 0.7565, 0.7626, 0.7556]
# [0.8475, 0.6178, 0.6961, 0.7565, 0.7626, 0.7556, 0.7002]
# [0.8475, 0.6178, 0.6961, 0.7565, 0.7626, 0.7556, 0.7002, 0.7615]
# [0.8475, 0.6178, 0.6961, 0.7565, 0.7626, 0.7556, 0.7002, 0.7615, 0.7601]
# [0.8475, 0.6178, 0.6961, 0.7565, 0.7626, 0.7556, 0.7002, 0.7615, 0.7601, 0.7605]
# [0.8475, 0.6178, 0.6961, 0.7565, 0.7626, 0.7556, 0.7002, 0.7615, 0.7601, 0.7605, 0.6959]
# [0.8475, 0.6178, 0.6961, 0.7565, 0.7626, 0.7556, 0.7002, 0.7615, 0.7601, 0.7605, 0.6959, 0.7606]
# [0.8475, 0.6178, 0.6961, 0.7565, 0.7626, 0.7556, 0.7002, 0.7615, 0.7601, 0.7605, 0.6959, 0.7606, 0.7559]
# [0.8475, 0.6178, 0.6961, 0.7565, 0.7626, 0.7556, 0.7002, 0.7615, 0.7601, 0.7605, 0.6959, 0.7606, 0.7559, 0.7605]
# ...

# %% [markdown]
# ### Escape Character

# %%
x = 'We just received $10.00 for cookies.'
y = re.findall('\$[0-9.]+',x)
print(y)

# %% [markdown]
# ### Assignment
#
# If you want a special regular expression character to just behave normally (most of the time) you prefix it with '\'

# %%
texto = open ('/content/drive/My Drive/Cursos/Data Science/Python for Everybody/3 Using Python to Access Web Data/regex_sum_42.txt')

x=list()

for line in texto:
     y = re.findall('[0-9]+',line)
     x = x + y

sum=0
for z in x:
    sum = sum + int(z)

print(sum)
# Out:
# 445833

# %%
texto = open ('/content/drive/My Drive/Cursos/Data Science/Python for Everybody/3 Using Python to Access Web Data/regex_sum_42.txt')

numlist = list()

for line in texto:
    line = line.rstrip()
    num = re.findall('[0-9]+', line)
    lista = numlist.append(num)  

soma = 0

for i in lista :
  soma = soma + i

print (soma)

 #DESSE JEITO NÃO FUNCIONA

# %% [markdown]
# ## Networked Technology

# %% [markdown]
# ### SOCKET

# %%
import socket ## BIBLIOTECA PARA SUPORTE A TCP SOCKET

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect( ('data.pr4e.org', 80) )

# %%
# An HTTP Request in Python

import socket
mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))
cmd = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\r\n\r\n'.encode()  ## encode ()--> tranformar Unicode em UTF-8/bytes 
mysock.send(cmd) ## send ()--> mandar o pedido 

while True:
    data = mysock.recv(512)  ## recv () --> para receber os dados 
    if (len(data) < 1):
        break
    print(data.decode(),end='')  ## decode () --> para voltar os dados para unicode
mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Tue, 10 Nov 2020 18:34:55 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "a7-54f6609245537"
# Accept-Ranges: bytes
# Content-Length: 167
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %%
import socket
mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))
cmd = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\n\n'.encode()   ## \n\n --> são so 2 enter utilizado no prompt  | se utilizar \r\n\r\n volta o texto em como em cima
#cmd = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\r\n\r\n'.encode()   ## \n\n --> são so 2 enter utilizado no prompt  | se utilizar \r\n\r\n volta o texto em como em cima
mysock.send(cmd)
while True:
    data = mysock.recv(512)
    if (len(data) < 1):
        break
    print(data.decode())
mysock.close()
# Out:
# HTTP/1.1 400 Bad Request
# Date: Tue, 10 Nov 2020 18:37:00 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Content-Length: 308
# Connection: close
# Content-Type: text/html; charset=iso-8859-1
#
# <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>400 Bad Request</title>
# </head><body>
# <h1>Bad Request</h1>
# <p>Your browser sent a request that this server could not understand.<br />
# </p>
# <hr>
# <address>Apache/2.4.18 (Ubuntu) Server at do1.dr-chuck.com Port 80</address>
# </body></html>

# %% [markdown]
# ### URLLIB
#
# Since HTTP is so common, we have a library that does all the socket work for us and makes web pages look like a file

# %%
# PODEMOS CHAMAR UM ARQUIVO DA INTERNET

import urllib.request

fhand = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')
for line in fhand:
    print(line.decode().strip())
# Out:
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %%
# PODEMOS CHAMAR UMA PAGINA DA INTERNET

import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('http://www.dr-chuck.com/page1.htm')
for line in fhand:
    print(line.decode().strip())
# Out:
# <h1>The First Page</h1>
# <p>
# If you like, you can switch to the
# <a href="http://www.dr-chuck.com/page2.htm">
# Second Page</a>.
# </p>

# %%
# USANDO O urllib + CONTADOR DE PALAVRAS 

import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')

counts = dict()
for line in fhand:
    words = line.decode().split()
    for word in words:
        counts[word] = counts.get(word, 0) + 1
print(counts)
# Out:
# {'But': 1, 'soft': 1, 'what': 1, 'light': 1, 'through': 1, 'yonder': 1, 'window': 1, 'breaks': 1, 'It': 1, 'is': 3, 'the': 3, 'east': 1, 'and': 3, 'Juliet': 1, 'sun': 2, 'Arise': 1, 'fair': 1, 'kill': 1, 'envious': 1, 'moon': 1, 'Who': 1, 'already': 1, 'sick': 1, 'pale': 1, 'with': 1, 'grief': 1}

# %% [markdown]
# ### BEAUTIFULSOUP

# %%
import urllib.request, urllib.parse, urllib.error

from bs4 import BeautifulSoup
url = input('Enter - ')
html = urllib.request.urlopen(url).read()
soup = BeautifulSoup(html, 'html.parser')

# Retrieve all of the anchor tags
tags = soup('a')
for tag in tags:
    print(tag.get('href', None))
# Out:
# Enter - http://www.dr-chuck.com/page1.htm
# http://www.dr-chuck.com/page2.htm

# %%
# To run this, download the BeautifulSoup zip file
# http://www.py4e.com/code3/bs4.zip
# and unzip it in the same directory as this file

import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urllib.request.urlopen(url, context=ctx).read()
soup = BeautifulSoup(html, 'html.parser') ## pega o texto todo misturado e retorna ele limpo

# Retrieve all of the anchor tags
tags = soup('a') ## a são as tag (<a)
for tag in tags:
    print(tag.get('href', None))
# Out:
# Enter - https://pt.wikipedia.org/wiki/Wikip%C3%A9dia:P%C3%A1gina_principal
# None
# #mw-head
# #searchInput
# /wiki/Wikip%C3%A9dia:Boas-vindas
# /wiki/Wikip%C3%A9dia
# /wiki/Enciclop%C3%A9dia
# /wiki/Conte%C3%BAdo_livre
# /wiki/Ajuda:Tutorial/Edi%C3%A7%C3%A3o
# /wiki/Wikip%C3%A9dia:Artigo
# /wiki/L%C3%ADngua_portuguesa
# /wiki/Especial:Estat%C3%ADsticas
# /wiki/Ajuda:P%C3%A1gina_principal
# /wiki/Wikip%C3%A9dia:Navegue
# /wiki/Ajuda:Perguntas_frequentes
# /wiki/Wikip%C3%A9dia:Pol%C3%ADticas_e_recomenda%C3%A7%C3%B5es
# /wiki/Portal:%C3%8Dndice
# /wiki/Portal:Arte
# /wiki/Portal:Biografias
# /wiki/Portal:Ci%C3%AAncia
# /wiki/Portal:Filosofia
# /wiki/Portal:Geografia
# /wiki/Portal:Hist%C3%B3ria
# /wiki/Portal:Matem%C3%A1tica
# /wiki/Portal:Sociedade
# /wiki/Portal:Tecnologia
# /wiki/Ficheiro:Rainer_Maria_Rilke,_1900.jpg
# /wiki/Elegias_de_Duino
# /wiki/Elegia
# /wiki/Bo%C3%A9mia
# /wiki/Austr%C3%ADaco
# /wiki/Rainer_Maria_Rilke
# ...

# %% [markdown]
# ## Web Services

# %% [markdown]
# ### XML
#
# eXtensible Markup Language

# %%
import xml.etree.ElementTree as ET

data = '''
<person>
  <name>Chuck</name>
  <phone type="intl">
    +1 734 303 4456
  </phone>
  <email hide="yes" />
</person>'''

tree = ET.fromstring(data)
print('Name:', tree.find('name').text)
print('Attr:', tree.find('email').get('hide'))
# Out:
# Name: Chuck
# Attr: yes

# %%
import xml.etree.ElementTree as ET

input = '''
<stuff>
  <users>
    <user x="2">
      <id>001</id>
      <name>Chuck</name>
    </user>
    <user x="7">
      <id>009</id>
      <name>Brent</name>
    </user>
  </users>
</stuff>'''

stuff = ET.fromstring(input)
lst = stuff.findall('users/user')
print('User count:', len(lst))

for item in lst:
    print('Name', item.find('name').text)
    print('Id', item.find('id').text)
    print('Attribute', item.get('x'))
# Out:
# User count: 2
# Name Chuck
# Id 001
# Attribute 2
# Name Brent
# Id 009
# Attribute 7

# %%
import urllib.request, urllib.parse, urllib.error
import xml.etree.ElementTree as ET
import ssl



api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/xml?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/xml?'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    address = input ("Enter location:" )  ## -> TypeError: 'str' object is not callable | but in prompt work very well
    if len(address) < 1: break

    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)
    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)

    data = uh.read()
    print('Retrieved', len(data), 'characters')
    print(data.decode())
    tree = ET.fromstring(data)

    results = tree.findall('result')
    lat = results[0].find('geometry').find('location').find('lat').text
    lng = results[0].find('geometry').find('location').find('lng').text
    location = results[0].find('formatted_address').text

    print('lat', lat, 'lng', lng)
    print(location)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-b2269c91e8ea> in <module>()
#      22
#      23 while True:
# ---> 24     address = input ("Enter location:" )  ## -> TypeError: 'str' object is not callable | but in prompt work very well
#      25     if len(address) < 1: break
#      26
#
# TypeError: 'str' object is not callable

# %%
import urllib.request, urllib.parse, urllib.error
import xml.etree.ElementTree as ET
import ssl

url = 'http://py4e-data.dr-chuck.net/comments_42.xml'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

print ("Retrieving", url)
html = urllib.request.urlopen(url, context=ctx)
data = html.read()
print("Retrieved",len(data),"characters")

tree = ET.fromstring(data)
results = tree.findall('comments/comment')
count=len(results)
sum=0

for result in results:
    #sum += int(result.find('count').text) ## x += n, is the same : x = x + n
    sum = sum + int(result.find('count').text) # I can use this too
print(count)
print(sum)
# Out:
# Retrieving http://py4e-data.dr-chuck.net/comments_42.xml
# Retrieved 4189 characters
# 50
# 2553.0

# %%
import urllib.request, urllib.parse, urllib.error
import xml.etree.ElementTree as ET
import ssl

url = 'http://py4e-data.dr-chuck.net/comments_1006557.xml'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

print ("Retrieving", url)
html = urllib.request.urlopen(url, context=ctx)
data = html.read() ## option 1
print("Retrieved",len(data),"characters")

tree = ET.fromstring(data)
results = tree.findall('comments/comment')
count=len(results)
sum=0

for result in results:
    sum += int(result.find('count').text)
print(count)
print(sum)
# Out:
# Retrieving http://py4e-data.dr-chuck.net/comments_1006557.xml
# Retrieved 4213 characters
# 50
# 2243

# %%
import urllib.request, urllib.parse, urllib.error
import xml.etree.ElementTree as ET
import ssl

url = 'http://py4e-data.dr-chuck.net/comments_1006557.xml'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

print ("Retrieving", url)
html = urllib.request.urlopen(url, context=ctx).read() ## option 2
print("Retrieved",len(html),"characters")

tree = ET.fromstring(html)
results = tree.findall('comments/comment')
count=len(results)
sum=0

for result in results:
    sum = sum + int (result.find('count').text)
print(count)
print(sum)
# Out:
# Retrieving http://py4e-data.dr-chuck.net/comments_1006557.xml
# Retrieved 4213 characters
# 50
# 2243

# %% [markdown]
# ### JSON
#
# **J**ava**S**cript **O**bject **N**otation

# %%
# like a dictionary

import json

data = '''
{
  "name" : "Chuck",
  "phone" : {
    "type" : "intl",
    "number" : "+1 734 303 4456"
   },
   "email" : {
     "hide" : "yes"
   }
}'''

info = json.loads(data)
print('Name:', info["name"])
print('Hide:', info["email"]["hide"])
# Out:
# Name: Chuck
# Hide: yes

# %%
# like a list

import json

data = '''
[
  { "id" : "001",
    "x" : "2",
    "name" : "Chuck"
  } ,
  { "id" : "009",
    "x" : "7",
    "name" : "Brent"
  }
]'''

info = json.loads(data)
print('User count:', len(info))

for item in info:
    print('Name', item['name'])
    print('Id', item['id'])
    print('Attribute', item['x'])
# Out:
# User count: 2
# Name Chuck
# Id 001
# Attribute 2
# Name Brent
# Id 009
# Attribute 7

# %%
#Option 1

import json
import urllib.request, urllib.parse, urllib.error
import ssl

url = 'http://py4e-data.dr-chuck.net/comments_42.json'  # the test link
#url = 'http://py4e-data.dr-chuck.net/comments_1006558.json'
# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

print ("Retrieving", url) # Retrieving http://py4e-data.dr-chuck.net/comments_42.json
data = urllib.request.urlopen(url, context=ctx).read()
print ("Retrieved", len(data),"characters") # Retrieved 2711 characters


sum = 0
info = json.loads(data)
for item in info["comments"]:
	sum += int(item["count"])
	
print (sum)
# Out:
# Retrieving http://py4e-data.dr-chuck.net/comments_1006558.json
# Retrieved 2715 characters
# 2893

# %%
#Option 2

import json
import urllib.request, urllib.parse, urllib.error
import ssl


url = input("Enter location: ")

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# read the json
data = urllib.request.urlopen(url, context=ctx).read()

# sum the comments
sum = 0
info = json.loads(data)
for item in info["comments"]:
	sum += int(item["count"])

print ("Retrieving ", url) # Retrieving http://py4e-data.dr-chuck.net/comments_42.json
print ("Retrieved " + str(len(data)) + " characters") # Retrieved 2711 characters
print ("Count: " + str(len(comments))) #Count: 50
print ("Sum: " + str(sum)) # Sum : 2711
# Out:
# Enter location: http://py4e-data.dr-chuck.net/comments_42.json
# Retrieving  http://py4e-data.dr-chuck.net/comments_42.json
# Retrieved 2711 characters
# Count: 50
# Sum: 2553

# %%
#Option 3

import json
import urllib.request, urllib.parse, urllib.error
import ssl


url = input("Enter location: ")  

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# read the json
data = urllib.request.urlopen(url, context=ctx).read()

# sum the comments
sum = 0
info = json.loads(data)
for item in info["comments"]:
	sum += int(item["count"])
	
# print the answers
print ("Retrieving ", url) # Retrieving http://py4e-data.dr-chuck.net/comments_42.json  OR http://py4e-data.dr-chuck.net/comments_1006558.json
print ("Retrieved", len(data), "characters") # Retrieved 2711 OR 2715 characters 
print ("Count: ", (len(comments))) #Count: 50
print ("Sum: ", sum) # Sum : 2553  OR 2893
# Out:
# Enter location: http://py4e-data.dr-chuck.net/comments_1006558.json
# Retrieving  http://py4e-data.dr-chuck.net/comments_1006558.json
# Retrieved 2715 characters
# Count:  50
# Sum:  2893

# %% [markdown]
# ## API
#
# Application Program Interface

# %%
import urllib.request, urllib.parse, urllib.error
import json
import ssl

api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')

    try:
        js = json.loads(data)
    except:
        js = None

    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue

    print(json.dumps(js, indent=4))

    lat = js['results'][0]['geometry']['location']['lat']
    lng = js['results'][0]['geometry']['location']['lng']
    print('lat', lat, 'lng', lng)
    location = js['results'][0]['formatted_address']
    print(location)

# %%
# Option 1


import urllib.request, urllib.parse, urllib.error
import json
import ssl


api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'


# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# sample_address = "South Federal University"
address = "South Federal University"


#Setting the GET parameters on the URL
parameters = {"address": address, "key":api_key}
url = urllib.parse.urlencode(parameters)
url = serviceurl.strip() + url.strip()


print('Retrieving', url)
uh = urllib.request.urlopen(url, context=ctx)
data = uh.read().decode()
print('Retrieved', len(data), 'characters')

#Obtaining and reading the data
jsondata = json.loads(data)
print(jsondata)
place_id = jsondata["results"][0]["place_id"]
print("PLACE ID: ", place_id)
# Out:
# Retrieving http://py4e-data.dr-chuck.net/json?address=South+Federal+University&key=42
# Retrieved 2290 characters
# ...

# %%
# Option 2


import urllib.request, urllib.parse, urllib.error
import json
import ssl


api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'


# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

# sample_address = "South Federal University"
address = "South Federal University"


#Setting the GET parameters on the URL
parameters = {"address": address, "key":api_key}
url = urllib.parse.urlencode(parameters)
url = serviceurl.strip() + url.strip()

print('Retrieving', url)
uh = urllib.request.urlopen(url, context=ctx)
data = uh.read().decode()
print('Retrieved', len(data), 'characters')

#Obtaining and reading the data
try :
    # Parsing the data and looking for the field we want.
    jsondata = json.loads(data)
    
    print(jsondata)
    place_id = jsondata["results"][0]["place_id"]
    print("PLACE ID: ", place_id)
except:
    print("Error.....")
    print("-"*50)
    print(data)
# Out:
# Retrieving http://py4e-data.dr-chuck.net/json?address=South+Federal+University&key=42
# Retrieved 2290 characters
# ...

# %%
# Option 3

import urllib.request, urllib.parse, urllib.error
import json
import ssl


api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'


# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    address = input('Enter location: ')
    if address == "done": 
      break

    #Setting the GET parameters on the URL
    parameters = {"address": address, "key":api_key}
    url = urllib.parse.urlencode(parameters)
    url = serviceurl.strip() + url.strip()
    
    
    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')
    
    
    
    #Obtaining and reading the data
    try :
        # Parsing the data and looking for the field we want.
        jsondata = json.loads(data)
    
        print(jsondata)
        place_id = jsondata["results"][0]["place_id"]
        print("PLACE ID: ", place_id)
        print ('='*50)
    except:
        print("Error.....")
        print("-"*50)
        print(data)
# Out:
# Enter location: rua caramurus
# Retrieving http://py4e-data.dr-chuck.net/json?address=rua+caramurus&key=42
# Retrieved 1940 characters
# ...
